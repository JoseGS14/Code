# %% [markdown]
# # PROGRAM #1.
# ## Calculates 1)Sample Mean, 2)Mode or 3)Standard Deviation
# ### Members:
# ### Gonzalez Santiago Jose Guadalupe
# ### Lopez Del Angel Luis Fernando
# ## MEC 3E

# %%
from collections import Counter
import math
 
a = int(input("Enter the number of data to introduce: "))
x = []
y = 0
w = a
i=0
v = a
r = 1
t = 0
u = 0
o = 1
c = 0
sv=0
prt=0 

while a >= 1:
    print("Introduce the data: " ,r)
    h = float(input())
    x.append(h)
    r = r + 1 
    a = a - 1 
    t = t + x[y] 
    y = y + 1 
    
pr = t / v 

while w >= 1:
    u = u + (x[o-1] - pr) ** 2
    w = w - 1
    o = o + 1

j = u / (v-1)
s = math.sqrt(j)
m=Counter(x).most_common()[0][0]



print("What would you like to calculate?\n1)Simple Mean\n2)Mode\n3)Standard Deviation\n")
while c == 0:
    l = float(input("> "))
    if l == 1:
        print(f"The Simple Mean is: {pr}")
        c = 1
        
        while i < 1:    
            print("Introduce the data: ")
            h = float(input())
            x.append(h)
       
            if x != 0:
                r=r+1
                a = a - 1 
                t = t + x[y] 
                y = y + 1
                sv= v+1
                prt = t / sv
            
                print(f"The Simple Mean is: {prt}") 
        
    if l == 2:
        print(f"The Mode Is: {m}")
        c = 1
        
        while i < 1:    
            print("Introduce the data: ")
            h = float(input())
            x.append(h)
            
            if x != 0:
                m=Counter(x).most_common()[0][0]
                print(f"The Mode Is: {m}")            
                
    if l == 3:
        print(f"The Standard Deviation is: {s}")
        c = 1
        
        while i < 1:    
            print("Introduce the data: ")
            h = float(input())
            x.append(h)
            
            if x != 0:
                r = r + 1 
                a = a - 1 
                t = t + x[y] 
                y = y + 1 
                sv= v+ 1
                pr = t / sv 
                u = u + (x[o-1] - pr) ** 2
                w = w - 1
                o = o + 1
                j = u / (sv-1)
                s = math.sqrt(j)
                
                print(f"The Standard Deviation is: {s}")
                
    elif l == 0 or l > 3:
        print("Introduce a correct number")
